# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.11.1

# %%
#zbiór MNIST
mnist = tf.keras.datasets.mnist

# %%
(x_train,y_train),(x_test,y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step

# %%
x_train, x_test = x_train/255.0, x_test/255.0

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
#model sieci neuronowej
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10)
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.2975 - accuracy: 0.9136
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1433 - accuracy: 0.9569
# Epoch 3/10
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.1053 - accuracy: 0.9678
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0880 - accuracy: 0.9727
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0734 - accuracy: 0.9768
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0646 - accuracy: 0.9794
# Epoch 7/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0579 - accuracy: 0.9817
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0519 - accuracy: 0.9831
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0470 - accuracy: 0.9844
# Epoch 10/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0447 - accuracy: 0.9852

# %%
#ocena modelu
test_loss,test_acc = model.evaluate(x_test,y_test)
print(f"strata: {test_loss}")
print(f"dopasowanie: {test_acc}")
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0693 - accuracy: 0.9799
# strata: 0.06925109028816223
# dopasowanie: 0.9799000024795532
